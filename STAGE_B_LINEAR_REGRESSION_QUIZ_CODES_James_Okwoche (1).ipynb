# %% [markdown]
# <h1 align="center">Hamoye Data Science Internship </h1>
# <h1 align="center"> Stage_A Assessment Codes </h1>

# %% [markdown]
# ---

# %% [markdown]
# ### By  Okwoche, James Ogate
# #### (Hamoye Data Science Intern - 2020 Cohort)

# %% [markdown]
# ---

# %% [markdown]
# ### Solution Sheet

# %%
# Importing the necessary Libraries
import pandas as pd
import seaborn as sns

#Load the data (directly from the github link) and read it's content
#Energy_Data = pd.read_csv('https://raw.githubusercontent.com/LuisM78/Appliances-energy-prediction-data/master/energydata_complete.csv')
Energy_Data = pd.read_csv(r'C:\Users\JAMES_OK\Desktop\HAMOYE\Stage_B\energydata_complete.csv')

# %%
# print the first 10 rows of the data, to be sure it has correctly loaded it
Energy_Data.head(10)
# Out:
#                   date  Appliances  lights         T1       RH_1     T2  \
# 0  2016-01-11 17:00:00          60      30  19.890000  47.596667  19.20
# 1  2016-01-11 17:10:00          60      30  19.890000  46.693333  19.20
# 2  2016-01-11 17:20:00          50      30  19.890000  46.300000  19.20
# 3  2016-01-11 17:30:00          50      40  19.890000  46.066667  19.20
# 4  2016-01-11 17:40:00          60      40  19.890000  46.333333  19.20
# 5  2016-01-11 17:50:00          50      40  19.890000  46.026667  19.20
# 6  2016-01-11 18:00:00          60      50  19.890000  45.766667  19.20
# 7  2016-01-11 18:10:00          60      50  19.856667  45.560000  19.20
# 8  2016-01-11 18:20:00          60      40  19.790000  45.597500  19.20
# 9  2016-01-11 18:30:00          70      40  19.856667  46.090000  19.23
#
#         RH_2     T3       RH_3         T4  ...         T9   RH_9     T_out  \
# 0  44.790000  19.79  44.730000  19.000000  ...  17.033333  45.53  6.600000
# ...

# %%
#Drop light and Date columns
Energy_Data = Energy_Data.drop(columns=['date', 'lights'])
Energy_Data.head(5)
# Out:
#    Appliances     T1       RH_1    T2       RH_2     T3       RH_3         T4  \
# 0          60  19.89  47.596667  19.2  44.790000  19.79  44.730000  19.000000
# 1          60  19.89  46.693333  19.2  44.722500  19.79  44.790000  19.000000
# 2          50  19.89  46.300000  19.2  44.626667  19.79  44.933333  18.926667
# 3          50  19.89  46.066667  19.2  44.590000  19.79  45.000000  18.890000
# 4          60  19.89  46.333333  19.2  44.530000  19.79  45.000000  18.890000
#
#         RH_4         T5  ...         T9   RH_9     T_out  Press_mm_hg  RH_out  \
# 0  45.566667  17.166667  ...  17.033333  45.53  6.600000        733.5    92.0
# 1  45.992500  17.166667  ...  17.066667  45.56  6.483333        733.6    92.0
# 2  45.890000  17.166667  ...  17.000000  45.50  6.366667        733.7    92.0
# 3  45.723333  17.166667  ...  17.000000  45.40  6.250000        733.8    92.0
# 4  45.530000  17.200000  ...  17.000000  45.40  6.133333        733.9    92.0
#
# ...

# %%
#rename the columns
column_names = {'date':'Date', 'Appliances': 'Appliances energy use in Wh', 
                'lights': 'lights energy use of fixtures in Wh', 'T1': 'Temperature in kitchen area, in Celsius', 
                'RH_1': 'Humidity in kitchen area, in %',
                'T2': 'Temperature in living room area, in Celsius', 
                'RH_2': 'Humidity in living room area, in %', 
                'T3': 'Temperature in laundry room area', 
                'RH_3': ' Humidity in laundry room area, in %', 
                'T4': 'Temperature in office room, in Celsius', 'RH_4': 'Humidity in office room, in %', 
                'T5': 'Temperature in bathroom, in Celsius','RH_5': 'Humidity in bathroom, in %',
                'T6': 'Temperature outside the building, in Celsius', 
                'RH_6': 'Outside Humidity in %', 'T7':'Temperature in ironing room in Celsius',
                'RH_7':'Humidity in ironing room, in %','T8': 'Temperature in teenager room 2, in Celsius',
                'RH_8': 'Humidity in teenager room 2, in %', 'T9': 'Temperature in parents room, in Celsius',
                'RH_9': 'Humidity in parents room, in %', 'T_out': 'Outside Temperature, in Celsius',
                'Press_mm_hg': 'Pressure, in mm Hg', 'RH_out': 'Outside_Humidity, in %',
                'Windspeed': 'Wind speed, in m/s', 'Visibility': 'Visibility, in km', 'Tdewpoint': 'Dewpoint , Â°C', 
                'rv1': 'Random variable 1', 'rv2': 'Random variable 2'}
Energy_Data = Energy_Data.rename(columns=column_names)
#increase the printed column to be able to view all columns
pd.options.display.max_columns = 30
#print the first 5 rows
Energy_Data.head(5)
# Out:
#    Appliances energy use in Wh  Temperature in kitchen area, in Celsius  \
# 0                           60                                    19.89
# 1                           60                                    19.89
# 2                           50                                    19.89
# 3                           50                                    19.89
# 4                           60                                    19.89
#
#    Humidity in kitchen area, in %  \
# 0                       47.596667
# 1                       46.693333
# 2                       46.300000
# 3                       46.066667
# 4                       46.333333
#
#    Temperature in living room area, in Celsius  \
# 0                                         19.2
# 1                                         19.2
# 2                                         19.2
# 3                                         19.2
# 4                                         19.2
#
# ...

# %%
#normalise the dataset to a common scale using the min max scaler
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
normalised_Data = pd.DataFrame(scaler.fit_transform(Energy_Data), columns = Energy_Data.columns)
normalised_Data.head(5)
# Out:
#    Appliances energy use in Wh  Temperature in kitchen area, in Celsius  \
# 0                     0.046729                                  0.32735
# 1                     0.046729                                  0.32735
# 2                     0.037383                                  0.32735
# 3                     0.037383                                  0.32735
# 4                     0.046729                                  0.32735
#
#    Humidity in kitchen area, in %  \
# 0                        0.566187
# 1                        0.541326
# 2                        0.530502
# 3                        0.524080
# 4                        0.531419
#
#    Temperature in living room area, in Celsius  \
# 0                                     0.225345
# 1                                     0.225345
# 2                                     0.225345
# 3                                     0.225345
# 4                                     0.225345
#
# ...

# %%
#Define feature and target variable
features_df = normalised_Data.drop(columns=['Appliances energy use in Wh'])
heating_target = normalised_Data['Appliances energy use in Wh']

#split  the dataset into the training and testing dataset. 
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(features_df, heating_target, train_size = 0.7,test_size=0.3, random_state=42)

# %%
#Multiple Linear Regression
from sklearn.linear_model import LinearRegression
linear_model = LinearRegression()
#fit the model to the training dataset
linear_model.fit(x_train, y_train)
#obtain predictions
predicted_values = linear_model.predict(x_test)
#predicted_values = pd.DataFrame(predicted_values)
predicted_values
# Out:
# array([0.03322207, 0.24411599, 0.03400024, ..., 0.06844707, 0.10032325,
#        0.05722198])

# %% [markdown]
# ## Quiz Solution

# %% [markdown]
# ### Question 1
#
# In linear regression, L2 regularization is equivalent to imposing a:
# #### Gaussian prior

# %% [markdown]
# ### Question 2
#
# Cross validation:
# #### Is often used to select hyperparameters

# %% [markdown]
# ### Question 3
# Ridge regression:
# #### Reduces variance at the expense of higher bias

# %% [markdown]
# ### Question 4
#
# In the different terms of the bias-variance tradeoff, which of the following is substantially more harmful to the test error than the training error?
#
# #### Variance

# %% [markdown]
# ### Question 5
# What can you use to find the best fit line for data in Linear Regression:
# #### Least Square Error

# %% [markdown]
# ### Question 6
# Which of the following sentence is true about outliers in Linear Regression:
# #### Linear regression is sensitive to outliers

# %% [markdown]
# ### Question 7
# How many coefficients do you need to estimate a simple linear regression model (One independent variable)?
# #### 2

# %% [markdown]
# ### Question 8
# Adding more basis functions in a linear model:
# #### Decreases variance

# %% [markdown]
# ### Question 9
# A best fit line relating X and Y has a R-Squared value of 0.75. How do I interpret this information?
# #### 75% of the variance in Y is explained by X

# %% [markdown]
# ### Question 10
# The Lasso can be interpreted as least-squares linear regression where:
# #### Weights are regularized with the L1 norm

# %% [markdown]
# ### Question 11
# Which of these is not an assumption of Linear Regression?
# #### Multivariate normality

# %% [markdown]
# ### Question 12: Linear Model

# %%
heating_target1 = Energy_Data['Temperature outside the building, in Celsius']
features_df1 = Energy_Data['Temperature in living room area, in Celsius']
#select a sample of the dataset
simple_linear_reg_df = Energy_Data[['Temperature in living room area, in Celsius','Temperature outside the building, in Celsius']]#.sample(15, random_state=2)
#regression plot
sns.regplot(x="Temperature in living room area, in Celsius", y="Temperature outside the building, in Celsius", 
            data=simple_linear_reg_df)

# %%
# R^2
from sklearn.metrics import r2_score
r2_score = r2_score(heating_target1, features_df1)
round(r2_score, 2)
# Out:
# -3.72

# %% [markdown]
# ## Model Evaluation
# ### Question 13: MAE

# %%
#MAE
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(y_test, predicted_values)
round(mae, 2)
# Out:
# 0.05

# %% [markdown]
# ### Question 14:  Sum of Squares Residual

# %%
import numpy as np
rss = np.sum(np.square(y_test - predicted_values))
round(rss, 2)
# Out:
# 45.35

# %% [markdown]
# ### Question 15: Root Mean Square Error

# %%
from sklearn.metrics import  mean_squared_error
rmse = np.sqrt(mean_squared_error(y_test, predicted_values))
round(rmse, 3)
# Out:
# 0.088

# %% [markdown]
# ### Question 16:  Coefficient of Determination

# %%
from sklearn.metrics import r2_score
r2_score = r2_score(y_test, predicted_values)
round(r2_score, 2)
# Out:
# 0.15

# %% [markdown]
# ### Question 17: Lowest and Highest Weight

# %%
#compare the effects of different regularisation approach
def get_weights_df(model, feat, col_name):
  #this function returns the weight of every feature
  weights = pd.Series(model.coef_, feat.columns).sort_values()
  weights_df = pd.DataFrame(weights).reset_index()
  weights_df.columns = ['Features', col_name]
  weights_df[col_name].round(3)
  return weights_df

linear_model_weights = get_weights_df(linear_model, x_train, 'Linear_Model_Weight')
ridge_weights_df = get_weights_df(ridge_reg, x_train, 'Ridge_Weight')
lasso_weights_df = get_weights_df(lasso_reg, x_train, 'Lasso_weight')
final_weights = pd.merge(linear_model_weights, ridge_weights_df, on='Features')
final_weights = pd.merge(final_weights, lasso_weights_df, on='Features')
final_weights
# Out:
#                                         Features  Linear_Model_Weight  \
# 0             Humidity in living room area, in %            -0.456698
# 1                Outside Temperature, in Celsius            -0.321860
# 2    Temperature in living room area, in Celsius            -0.236178
# 3        Temperature in parents room, in Celsius            -0.189941
# 4              Humidity in teenager room 2, in %            -0.157595
# 5                         Outside_Humidity, in %            -0.077671
# 6                 Humidity in ironing room, in %            -0.044614
# 7                 Humidity in parents room, in %            -0.039800
# 8            Temperature in bathroom, in Celsius            -0.015657
# 9        Temperature in kitchen area, in Celsius            -0.003281
# 10                             Random variable 1             0.000770
# 11                             Random variable 2             0.000770
# ...

# %%
print(linear_model_weights .sort_values(by=['Linear_Model_Weight'] , ascending=False))
# Out:
#                                         Features  Linear_Model_Weight
# 25                Humidity in kitchen area, in %             0.553547
# 24              Temperature in laundry room area             0.290627
# 23  Temperature outside the building, in Celsius             0.236425
# 22                                Dewpoint , Â°C             0.117758
# 21    Temperature in teenager room 2, in Celsius             0.101995
# 20           Humidity in laundry room area, in %             0.096048
# 19                         Outside Humidity in %             0.038049
# 18                            Wind speed, in m/s             0.029183
# 17        Temperature in office room, in Celsius             0.028981
# 16                 Humidity in office room, in %             0.026386
# 15                    Humidity in bathroom, in %             0.016006
# 14                             Visibility, in km             0.012307
# ...

# %% [markdown]
# ### Question 18: Ridge Regression RMSE Value

# %%
#Ridge regression at alpha 0.5
from sklearn.linear_model import Ridge
ridge_reg = Ridge(alpha=0.4)
ridge_reg.fit(x_train, y_train)
#rmse
from sklearn.metrics import  mean_squared_error
rmse = np.sqrt(mean_squared_error(y_test, pred))
round(rmse, 3)
# Out:
# 0.088

# %% [markdown]
# #### No change in the RMSE Value after training the ridge

# %% [markdown]
# ### Question 19: Lasso training

# %%
#Lasso regression at alpha 0.001
from sklearn.linear_model import Lasso
lasso_reg = Lasso(alpha=0.001)
lasso_reg.fit(x_train, y_train)

#compare the effects of different regularisation approach
def get_weights_df(model, feat, col_name):
  #this function returns the weight of every feature
  weights = pd.Series(model.coef_, feat.columns).sort_values()
  weights_df = pd.DataFrame(weights).reset_index()
  weights_df.columns = ['Features', col_name]
  weights_df[col_name].round(3)
  return weights_df

linear_model_weights = get_weights_df(linear_model, x_train, 'Linear_Model_Weight')
lasso_weights_df = get_weights_df(lasso_reg, x_train, 'Lasso_weight')
lasso_weights_df
# Out:
#                                         Features  Lasso_weight
# 0                         Outside_Humidity, in %     -0.049557
# 1              Humidity in teenager room 2, in %     -0.000110
# 2        Temperature in kitchen area, in Celsius      0.000000
# 3                                 Dewpoint , Â°C      0.000000
# 4                              Visibility, in km      0.000000
# 5                             Pressure, in mm Hg     -0.000000
# 6                Outside Temperature, in Celsius      0.000000
# 7                 Humidity in parents room, in %     -0.000000
# 8        Temperature in parents room, in Celsius     -0.000000
# 9     Temperature in teenager room 2, in Celsius      0.000000
# 10                Humidity in ironing room, in %     -0.000000
# 11                             Random variable 1     -0.000000
# 12        Temperature in ironing room in Celsius     -0.000000
# 13  Temperature outside the building, in Celsius      0.000000
# ...

# %% [markdown]
# ####  4 features has non zero weights

# %% [markdown]
# ### Question 20: New RMSE Value with Lasso

# %%
from sklearn.metrics import  mean_squared_error
rmse = np.sqrt(mean_squared_error(y_test, pred2))
round(rmse, 3) #Return 0.094
# Out:
# 0.094
